# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
chemin_donnees = "/content/drive/MyDrive/PIP2025/Etude sur les Français et l'Information/les-francais-et-l-information-propre.csv"
